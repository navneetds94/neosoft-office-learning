# %%
import re
import pandas as pd;
import matplotlib.pyplot as plt;

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Tigrov/geoname-divisions/master/result/divisions.csv',delimiter=";",
                 encoding="UTF-8")

# %%
df.head()
# Out:
#   ISO-3166-1 ISO-3166-2 Fips  GN  Geoname ID  Name of Subdivision  \
# 0         AD         02   02  02   3041203.0              Canillo
# 1         AD         03   03  03   3040684.0               Encamp
# 2         AD         04   04  04   3040131.0           La Massana
# 3         AD         05   05  05   3039676.0               Ordino
# 4         AD         06   06  06   3039162.0  Sant Julia de Lòria
#
#                                            Wikipedia  Type ID    Type  \
# 0               http://en.wikipedia.org/wiki/Canillo      1.0  parish
# 1                http://en.wikipedia.org/wiki/Encamp      1.0  parish
# 2            http://en.wikipedia.org/wiki/La_Massana      1.0  parish
# 3                http://en.wikipedia.org/wiki/Ordino      1.0  parish
# 4  http://en.wikipedia.org/wiki/Sant_Juli%C3%A0_d...      1.0  parish
#
#    Geoname ID of Capital              Capital  Population lang continent From  \
# ...

# %%
df2 = round(df.isnull().sum() / df.shape[0] * 100,2)

# %%
df2.sort_values(ascending=False)
# Out:
# Till                     99.80
# From                     95.21
# lang                     64.11
# continent                13.04
# Population                8.56
# Fips                      8.32
# Geoname ID of Capital     7.91
# Capital                   7.71
# ISO-3166-2                6.12
# Type ID                   5.10
# Type                      5.10
# Geoname ID                3.23
# Wikipedia                 3.23
# GN                        2.36
# ISO-3166-1                0.36
# Name of Subdivision       0.00
# dtype: float64

# %%
# df.to_csv("dvistion_data.csv")
