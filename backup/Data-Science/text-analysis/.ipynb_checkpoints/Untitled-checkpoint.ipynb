# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import os
import numpy as np

# %%
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service as ChromeService 
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
# Out:
# [WDM] - Downloading: 100%|█████████████████████████████████████████████████████████| 6.80M/6.80M [00:15<00:00, 453kB/s]

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36'}

# %%
driver.get("https://medium.com/")

# %%
htmlcontent = driver.page_source
htmlcontent
# Out:
# '<html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# " class="js fontawesome-i2svg-active fontawesome-i2svg-complete"><head>\n    <meta charset="utf-8">\n<script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=UA-54970022-1&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-P83LHMFZ97&amp;l=dataLayer&amp;cx=c"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-33406418-2"></script>\n<script>window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments)};gtag("js", new Date());gtag("set", "developer_id.dMDhkMT", true);gtag("config", "UA-33406418-2", {"groups":"default","anonymize_ip":true,"page_placeholder":"PLACEHOLDER_page_path"});gtag(\'config\', \'UA-54970022-1\', {\'name\': \'govcms\'}); gtag(\'govcms.send\', \'pageview\', {\'anonymizeIp\': true})</script>\n<link rel="canonical" href="https://www.acnc.gov.au/charity">\n<meta name="Generator" content="Drupal 9 (http://drupal.org) + GovCMS (http://govcms.gov.au)">\n<meta name="MobileOptimized" content="width">\n<meta name="HandheldFriendly" content="true">\n<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n<meta http-equiv="x-ua-compatible" content="ie=edge">\n<link rel="icon" href="/themes/custom/acnc/favicon.svg" type="image/svg+xml">\n\n    <title>Charity Register | ACNC</title>\n    <link rel="stylesheet" media="all" href="/sites/default/files/css/css_kcpJl2G6pY5K3VUDCOc-bNWZUn5aisTSW0wP2rqcOn8.css">\n<link rel="stylesheet" media="all" href="/modules/custom/acnc_charity_search/assets/dist/css/chunk/chunk-vendors.css?ru6g3h">\n<link rel="stylesheet" media="all" href="/modules/custom/acnc_charity_search/assets/dist/css/app.css?ru6g3h">\n<link rel="stylesheet" media="all" href="/sites/default/files/css/css_v52pnKvzGMwJsCsbQob1gLXKl-3n3S7iFQHISwvruAA.css">\n<link rel="stylesheet" media="all" href="/themes/custom/acnc/assets/dist/css/vendors.css?ru6g3h">\n<link rel="stylesheet" media="all" href="/themes/custom/acnc/assets/dist/css/app.css?ru6g3h">\n<link rel="stylesheet" media="print" href="/themes/custom/acnc/assets/dist/css/print.css?ru6g3h">\n\n    \n  <script>bazadebezolkohpepadr="1771721705"</script><script type="text/javascript" src="https://www.acnc.gov.au/akam/13/699a521d" defer=""></script><script charset="utf-8" src="/modules/custom/acnc_charity_search/assets/dist/js/chunk/chunk-2d21e30b.js?id=f63542042dcd35876d24"></script><script charset="utf-8" src="/modules/custom/acnc_charity_search/assets/dist/js/chunk/chunk-7a240ec6.js?id=1f1e9c3cc022fa32a842"></script></head>\n  <body class="layout-no-sidebars path-charity" style="">\n    <a href="#main-content" class="visually-hidden-focusable skip-link">\n      Skip to main content\n    </a>\n    \n      <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">\n    <a name="top"></a>\n<div id="page-wrapper">\n  <div id="page">\n\n    <header id="site-header" class="site-header" role="banner" aria-label="Site header">\n      \n      <div class="top py-4 bg-light">\n        <div class="container">\n\n          <div class="row">\n                        <div class="col-5 col-sm-4">\n                  <a href="/" title="Home" rel="home" class="logo-link d-inline-block">\n          <img src="/themes/custom/acnc/logo.svg" alt="Home" class="logo img-fluid">\n    \n    \n    \n  </a>\n\ ...
